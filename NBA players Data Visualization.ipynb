# %% [markdown]
# # Homework

# %% [markdown]
# ## Set Up

# %% [markdown]
# 1. Download the data from:
#
# [Kaggle - NBA Players Data](https://www.kaggle.com/justinas/nba-players-data)

# %% [markdown]
# 2. Upload the dataset to google colab
#
#   - Click the folder symbol on the left
#   ![Screen Shot 2021-09-10 at 11.13.24 AM.png](data:image/png;base64,...)

# %% [markdown]
# 3. Click the upload button:

# %% [markdown]
# ![Screen Shot 2021-09-10 at 11.15.29 AM.png](data:image/png;base64,...)

# %% [markdown]
# 4. Find the file and upload it:

# %% [markdown]
# ![Screen Shot 2021-09-10 at 11.19.18 AM.png](data:image/png;base64,...)

# %% [markdown]
# Now after a couple of seconds you should be able to see the file in colab.

# %% [markdown]
# ![Screen Shot 2021-09-10 at 11.21.52 AM.png](data:image/png;base64,...)

# %% [markdown]
# 5. Then run the code cell below to unzip the file.

# %%
## don't change this cell
# !unzip /content/all_seasons.csv
# Out:
# Archive:  /content/all_seasons.csv
#   End-of-central-directory signature not found.  Either this file is not
#   a zipfile, or it constitutes one disk of a multi-part archive.  In the
#   latter case the central directory and zipfile comment will be found on
#   the last disk(s) of this archive.
# unzip:  cannot find zipfile directory in one of /content/all_seasons.csv or
#         /content/all_seasons.csv.zip, and cannot find /content/all_seasons.csv.ZIP, period.

# %% [markdown]
# You should be seeing the file `all_seasons.csv` now.

# %% [markdown]
# ![Screen Shot 2021-09-10 at 11.23.26 AM.png](data:image/png;base64,...)

# %% [markdown]
# 6. Prepare the data. Run the cell below. Don't change anything there.

# %%
## Don't change anything in this cell

import pandas as pd
import seaborn as sns

nba_players = pd.read_csv('/content/all_seasons.csv', index_col = 0)

kobe = nba_players[nba_players.player_name == 'Kobe Bryant']
kobe_age = kobe.age.values
kobe_points = kobe.pts.values
seasons = kobe.season.values

# %% [markdown]
# ## Submitting Your Work
#
# Once you are finished use the link below to submit your work.
#
#   - Make sure that you named the file as `FirstName_LastName`
#
#   [Google Form](https://forms.gle/SMMfgyr9Gf7PBMne9)

# %% [markdown]
# # Problem

# %% [markdown]
# - Import matplotlib library's pyplot interface as plt

# %%
## Answer cell
import matplotlib.pyplot as plt
# %matplotlib inline

import matplotlib.ticker as ticker

# %% [markdown]
# # Problem-I

# %% [markdown]
# For this problem you can use `kobe_points`,`kobe_age` and `seasons` to plot Kobe Bryant's average points per seaons.

# %% [markdown]
# __Todos__
#
# 1. Add Title: `Kobe's average points over the seasons` - Here I want you to use apostrophe.
#
# 2. Y-labels and x-labels
#
# 3. Make sure that y-axis ticks are increasing by 2 points.
#
# 4. Grids
#
# 5. Margins
#
# 6. X-ticks should be seasons and they should be vertical.
#
# 7. Change the size of the figure. Choose the width and height that makes the most sense for you.

# %% [markdown]
# ![Screen Shot 2021-09-09 at 3.56.20 PM.png](data:image/png;base64,...)

# %%
## Answer cell
import numpy as np
plt.plot(kobe_age,kobe_points)
## Add Title:
plt.title("Kobe's average points over the seasons")

## X-labels and Y-labels
plt.xlabel('Seasons')
plt.ylabel("Average points per season")

## y-axis ticks are increasing by 2 points
plt.yticks(np.arange(0, 40, step=2))

## Grids
plt.grid()

##margins
plt.margins()

## X-ticks should be seasons and they should be vertical. 
plt.xticks(rotation='vertical')

width = 10
height = 10

fig = plt.figure(figsize = (width, height))
## Change the size of the figure. 


plt.show()

# %% [markdown]
# ## Problem-II

# %%
## Don't change this cell
player_heights = nba_players.groupby('player_name').player_height.mean().values

player_weights =  nba_players.groupby('player_name').player_weight.mean().values

player_pts = nba_players.groupby('player_name').gp.mean().values

# %% [markdown]
# Use `player_heights`, `player_weights` and `player_pts` to recreate the visualization below.

# %% [markdown]
# __Todos__
#
# 1. Scatter plot players height with respect to their weights. Make sure that height is in the x-axis.
#
# 2. The size of the points should change according to player's average points.
#
# 3. Set the transparency value to 0.7.
#
# 4. Add grids
#
# 5.
#   - Add annotations at x = 155, y = 65 as 'Muggsy Bogues'
#   - Add annotations at x = 226, y = 165, as  'Sim Bhullar'
#   - Add anootations at x= 233, y = 137, as 'Gheorghe Muresan'
#
# 6. Set x-label, y-label and title accordingly.
#
# 7. Use the style 'seaborn-poster'
#
# 8. Change the size of the figure. You can choose width and height.

# %% [markdown]
# ![Screen Shot 2021-09-09 at 4.44.06 PM.png](data:image/png;base64,...)

# %%
## answer cell
x = player_heights
y = player_weights

## 2.
## 3.
plt.scatter(x, y, s= player_pts, alpha=0.7)

## 4.
plt.grid(2)

## 5.
plt.text(155, 65, 'Muggsy Bogues')
plt.text(226, 165, 'Sim Bhullar')
plt.text(233, 137, 'Gheorghe Muresan')

## 6. 
plt.xlabel("Player's Height in cm")
plt.ylabel("Player's Weight in kg")

## 7. 
plt.style.use('seaborn-poster')

## 8. 
width = 15
height = 8

# %% [markdown]
# ## Problem-III

# %% [markdown]
# Use the `player_weights` array to show the NBA players' weight distribution. Recreate the figure below.
#
# __Todos__
#
# 1. Define a variable `m` as the average weights of the NBA players.
#
# 2. Define a variable `s` as the standard deviation of the NBA player's weights.
#
# 3. Create a histogram plot for `player_weights` and set the number of bins equal to 50.
#
# 4. Add the title, x-label, y-label.
#
# 5. Make annotations to show average and standard deviations of the player's weight. Make sure to use the variables `m` and `s` defined above in your annotation.
#
# 6. You can change the figure size, style and margins if you see the need but you are not required.

# %%
## Don't change this cell
player_weights;

# %% [markdown]
# ![Screen Shot 2021-09-09 at 4.55.11 PM.png](data:image/png;base64,...)

# %%
## Answer cell
fig, ax = plt.subplots()

m = nba_players.player_weight.mean()
s = nba_players.player_weight.std()

ax.hist(player_weights, bins=50)

ax.set_xlabel('Weight')
ax.set_ylabel('Counts')
ax.set_title("Distribution of NBA's weight")

ax.annotate(m, (105,160))
ax.annotate(s, (135,160))
# Out:
# Text(135, 160, '12.526480950815179')

# %%
print(m,s)
# Out:
# 100.52679086153996 12.526480950815179

# %%
nba_players.describe()
# Out:
#                 age  player_height  ...        ts_pct       ast_pct
# count  11700.000000   11700.000000  ...  11700.000000  11700.000000
# mean      27.131966     200.728501  ...      0.510402      0.131228
# std        4.340006       9.169827  ...      0.098306      0.094244
# min       18.000000     160.020000  ...      0.000000      0.000000
# 25%       24.000000     193.040000  ...      0.479000      0.065000
# 50%       26.000000     200.660000  ...      0.523000      0.103000
# 75%       30.000000     208.280000  ...      0.559000      0.178000
# max       44.000000     231.140000  ...      1.500000      1.000000
#
# [8 rows x 13 columns]

# %% [markdown]
# refernce: https://problemsolvingwithpython.com
# https://stackoverflow.com/
# https://matplotlib.org
